# %% [markdown]
# ## 파일 입출력
#
# #### 웹 -> 크롤링 -> 데이터베이스 -> 1차 클렌징 -> 출력 후 담당자에게 전달(구글시트) -> 2차 클렌징 ->유용한 데이터셋 -> csv 데이터베이스 입력 -> 인공지능 학습

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/Colab Notebooks/python
# Out:
# /content/drive/MyDrive/Colab Notebooks/python

# %% [markdown]
# r - 읽기
# w - 쓰기 ( 주의 : 덮어쓰기 )
# a - 추가

# %%
f = open('text.txt','w')
f.write('수강생 여러분')
f.close()

# %%
f = open('text.txt','w')
f.write('개발자 여러분')
f.close()

# %%
f = open('text.txt','w')
f.write('''개발자여러분
개발자여러분
개발자여러분
''')
f.close()

# %%
f = open('text.txt','w')
메시지 = ''

for i in range(10):
    메시지 += "개발자친구들 \n"

f.write(메시지)
f.close()

# %%
f = open('text.txt', 'r')
s = f.read()
print(s)
f.close()
# Out:
# 개발자친구들
# 개발자친구들
# 개발자친구들
# 개발자친구들
# 개발자친구들
# 개발자친구들
# 개발자친구들
# 개발자친구들
# 개발자친구들
# 개발자친구들

# %%
f = open('text.txt', 'r')
line = f.readline()
print(line)
print(type(line))
f.close()
# Out:
# 개발자친구들
#
# <class 'str'>

# %%
f = open('text.txt', 'r')

while line:
    line = f.readline()
    print(line)
f.close()
# Out:
# 개발자친구들
#
# 개발자친구들
#
# 개발자친구들
#
# 개발자친구들
#
# 개발자친구들
#
# 개발자친구들
#
# 개발자친구들
#
# 개발자친구들
#
# 개발자친구들
#
# 개발자친구들

# %%
f = open('text.txt', 'a')
f.write("힘내자")
f.close()

# %%
with open('text.txt', 'a') as f:
    f.write('힘내자!!!!!!')

# %%
list = [10,20,30]

with open('text.txt', 'a') as f:
    f.write(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3600712014.py in <cell line: 0>()
#       2
#       3 with open('text.txt', 'a') as f:
# ----> 4     f.write(list)
#
# TypeError: write() argument must be str, not list

# %%
list = [10,20,30]

with open('text.txt', 'a') as f:
    f.write(str(list))

# %%
list = [10,20,30]

with open('text.txt', 'w') as f:
    f.write('let text = '+ str(list))       # javascript 문법 적용

# %%
list = [10,20,30]

with open('text.txt', 'w') as f:
    f.writelines(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2210066394.py in <cell line: 0>()
#       2
#       3 with open('text.txt', 'w') as f:
# ----> 4     f.writelines(list)
#
# TypeError: write() argument must be str, not int

# %%
list = ['10','20','30']

with open('text.txt', 'w') as f:
    f.writelines(list)

# %%
# csv
list = ['10','20','30']

with open('test.csv', 'w') as f:
    f.write(','.join(list))
