# %%
# 주석은 이렇게 하는거다
print("진짜 안보이는 거야?")
# print("신기하네?")
# Out:
# 진짜 안보이는 거야?

# %%
# print("진짜 안보이는 거야?")
# print("신기하네?")
# 코랩은 전체 주석인 """""" 안먹힘

# %%
# 들여쓰기도 문법이다!
for 동물 in ("토끼", "사자", "푸바오", "호랑이"):
    print(동물)
    print("보러갈래요?")
# Out:
# 토끼
# 보러갈래요?
# 사자
# 보러갈래요?
# 푸바오
# 보러갈래요?
# 호랑이
# 보러갈래요?

# %%
for 동물 in ("토끼", "사자", "푸바오", "호랑이"):
    print(동물)
print("보러갈래요?")
# Out:
# 토끼
# 사자
# 푸바오
# 호랑이
# 보러갈래요?
